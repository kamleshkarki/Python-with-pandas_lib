# %%
#import library
import pandas as pd
import numpy as np
import pandasql as psql
import pandas_profiling

# %%
#Data from sample super store
#read sheet order
ord = pd.read_excel('desktop/Samplestore.xls','Orders')
ord.head(4)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0     42420.0   South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0   South  FUR-CH-10000454        Furniture       Chairs
# ...

# %%
ord.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9983 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
ord.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
ord.count()
# Out:
# Row ID           9994
# Order ID         9994
# Order Date       9994
# Ship Date        9994
# Ship Mode        9994
# Customer ID      9994
# Customer Name    9994
# Segment          9994
# Country          9994
# City             9994
# State            9994
# Postal Code      9983
# Region           9994
# Product ID       9994
# Category         9994
# Sub-Category     9994
# Product Name     9994
# Sales            9994
# Quantity         9994
# Discount         9994
# Profit           9994
# dtype: int64

# %%
people= pd.read_excel('desktop/Samplestore.xls','People')
people.head(4)
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
returns= pd.read_excel('desktop/Samplestore.xls','Returns')
returns.head()
# Out:
#   Returned        Order ID
# 0      Yes  CA-2015-100762
# 1      Yes  CA-2015-100762
# 2      Yes  CA-2015-100762
# 3      Yes  CA-2015-100762
# 4      Yes  CA-2015-100867

# %%
#Create report
#pandas_profiling.ProfileReport(order)

# %%
#order=psql.sqldf("select * from order")
# i have seen with the key word of order the key word replace with ord 
order= psql.sqldf("select * from ord")
order.head(4)
# Out:
#    Row ID        Order ID                  Order Date  \
# 0       1  CA-2017-152156  2017-11-08 00:00:00.000000
# 1       2  CA-2017-152156  2017-11-08 00:00:00.000000
# 2       3  CA-2017-138688  2017-06-12 00:00:00.000000
# 3       4  US-2016-108966  2016-10-11 00:00:00.000000
#
#                     Ship Date       Ship Mode Customer ID    Customer Name  \
# 0  2017-11-11 00:00:00.000000    Second Class    CG-12520      Claire Gute
# 1  2017-11-11 00:00:00.000000    Second Class    CG-12520      Claire Gute
# 2  2017-06-16 00:00:00.000000    Second Class    DV-13045  Darrin Van Huff
# 3  2016-10-18 00:00:00.000000  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City  ... Postal Code  Region  \
# 0   Consumer  United States        Henderson  ...     42420.0   South
# 1   Consumer  United States        Henderson  ...     42420.0   South
# 2  Corporate  United States      Los Angeles  ...     90036.0    West
# ...

# %%
people=psql.sqldf("select * from people")
people.head(4)
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
returns=psql.sqldf("select * from returns")
returns.head(4)
# Out:
#   Returned        Order ID
# 0      Yes  CA-2015-100762
# 1      Yes  CA-2015-100762
# 2      Yes  CA-2015-100762
# 3      Yes  CA-2015-100762

# %%
#left join on order and returns
df=psql.sqldf("select a.*,b.Returned from ord a left join returns b on a.[Order ID] = b.[Order ID]")
df.head()
# Out:
#    Row ID        Order ID                  Order Date  \
# 0       1  CA-2017-152156  2017-11-08 00:00:00.000000
# 1       2  CA-2017-152156  2017-11-08 00:00:00.000000
# 2       3  CA-2017-138688  2017-06-12 00:00:00.000000
# 3       4  US-2016-108966  2016-10-11 00:00:00.000000
# 4       5  US-2016-108966  2016-10-11 00:00:00.000000
#
#                     Ship Date       Ship Mode Customer ID    Customer Name  \
# 0  2017-11-11 00:00:00.000000    Second Class    CG-12520      Claire Gute
# 1  2017-11-11 00:00:00.000000    Second Class    CG-12520      Claire Gute
# 2  2017-06-16 00:00:00.000000    Second Class    DV-13045  Darrin Van Huff
# 3  2016-10-18 00:00:00.000000  Standard Class    SO-20335   Sean O'Donnell
# 4  2016-10-18 00:00:00.000000  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City  ... Region       Product ID  \
# 0   Consumer  United States        Henderson  ...  South  FUR-BO-10001798
# ...

# %%
#filling black with NAN to a specifis column
df["Returned"].fillna("NaN", inplace= True)

# %%
df.head()
# Out:
#    Row ID        Order ID                  Order Date  \
# 0       1  CA-2017-152156  2017-11-08 00:00:00.000000
# 1       2  CA-2017-152156  2017-11-08 00:00:00.000000
# 2       3  CA-2017-138688  2017-06-12 00:00:00.000000
# 3       4  US-2016-108966  2016-10-11 00:00:00.000000
# 4       5  US-2016-108966  2016-10-11 00:00:00.000000
#
#                     Ship Date       Ship Mode Customer ID    Customer Name  \
# 0  2017-11-11 00:00:00.000000    Second Class    CG-12520      Claire Gute
# 1  2017-11-11 00:00:00.000000    Second Class    CG-12520      Claire Gute
# 2  2017-06-16 00:00:00.000000    Second Class    DV-13045  Darrin Van Huff
# 3  2016-10-18 00:00:00.000000  Standard Class    SO-20335   Sean O'Donnell
# 4  2016-10-18 00:00:00.000000  Standard Class    SO-20335   Sean O'Donnell
#
#      Segment        Country             City  ... Region       Product ID  \
# 0   Consumer  United States        Henderson  ...  South  FUR-BO-10001798
# ...

# %%
#output to excel
df.to_excel('Desktop/temp.xlsx')

# %%
# using left join using merge with pandas
df1=pd.merge(ord,returns, how='left', on='Order ID')
df1.head(3)
# Out:
#    Row ID        Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11  Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11  Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City  ... Region  \
# 0      Claire Gute   Consumer  United States    Henderson  ...  South
# 1      Claire Gute   Consumer  United States    Henderson  ...  South
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...   West
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96        2
# ...
