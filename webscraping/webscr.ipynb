# %%
#Import pandas library
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tabulate import tabulate

# %%
#request for a web site site tto scrall web data
res= requests.get("https://www.worldometers.info/coronavirus/")

# %%
soup=BeautifulSoup(res.content,'lxml')

# %%
table=soup.find_all('table')[0]

# %%
df= pd.read_html(str(table))
#df.to_csv(r'C:\Users\RamaKrishna\Desktop\covid_19.csv')
#df.to_csv("C:\Users\RamaKrishna\Desktop\covid_19.csv")

# %%
#print(df[0].to_json(orient='records'))
print(tabulate(df[0], headers='keys', tablefmt='psql'))
# Out:
# +-----+------------------------+--------------+------------+---------------+-------------+------------------+---------------+--------------------+--------------------+-----------------+------------------+-----------------+
# |     | Country,Other          |   TotalCases | NewCases   |   TotalDeaths |   NewDeaths |   TotalRecovered |   ActiveCases |   Serious,Critical |   Tot Cases/1M pop |   Deaths/1M pop |       TotalTests |   Tests/ 1M pop |
# |-----+------------------------+--------------+------------+---------------+-------------+------------------+---------------+--------------------+--------------------+-----------------+------------------+-----------------|
# |   0 | World                  |      1435092 | +4,173     |         82191 |         157 |           302989 |       1049912 |              47958 |              184   |           10.5  |    nan           |             nan |
# ...

# %%
#df.to_excel('covid_19.xlsx')
#df.savetxt(r'C:\Users\RamaKrishna\Desktop\np.txt', df.values, fmt='%d', delimiter='\t')
#df = pd.read_excel(r'C:\Users\RamaKrishna\Desktop\covid_19.xlsx', sheet_name='covid_19', index = False)

# %%
df.to_csv (r'C:\Users\RamaKrishna\Desktop\covid_19.xlsx', index = False, header=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-cba92ebd23d0> in <module>
# ----> 1 df.to_csv (r'C:\Users\RamaKrishna\Desktop\covid_19.xlsx', index = False, header=True)
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
AttributeError: 'list' object has no attribute 'to_csv'
