# %%
import nltk
import sklearn
pd.__version__
print('The nltk version is {}.'.format(nltk.__version__))
print('The scikit-learn version is {}.'.format(sklearn.__version__))
print('The Pandas version is {}.'.format(pd.__version__))
# Out:
# The nltk version is 3.4.5.
# The scikit-learn version is 0.21.2.
# The Pandas version is 0.25.1.

# %%
import numpy as np
import pandas as pd 
import os

# %%
#df = pd.read_csv('C:/Users/ayn-pc2/Desktop/T/update.csv')
#df = pd.read_csv('C:/Users/ayn-pc2/Desktop/T/update.csv', sep='\t')
df = pd.read_csv('C:/Users/ayn-pc2/Desktop/T/update.csv')
#df
df.head()
# Out:
#    firstname  lastname                                            company
# 0  Mr. Vijay   Balotia  Khoobsurat Overseas was established in the yea...
# 1   Rajinder     Kumar  Intex Technologies India Ltd incorporated in 1...
# 2      Sunil   Khurana  Means redefining the meaning of beauty. An ama...
# 3      Madan      Soni  Born in East London Ive naturally been exposed...
# 4    Parveen     Kumar                                                NaN

# %%
df.columns
# Out:
# Index([' firstname', ' lastname', 'company'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=37249, step=1)

# %%
df.values
# Out:
# array([['Mr. Vijay', 'Balotia',
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (37249, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37249 entries, 0 to 37248
# Data columns (total 3 columns):
#  firstname    37231 non-null object
#  lastname     31744 non-null object
# company       33142 non-null object
# dtypes: object(3)
# memory usage: 873.1+ KB

# %%
df['company']
# Out:
# 0        Khoobsurat Overseas was established in the yea...
# 1        Intex Technologies India Ltd incorporated in 1...
# 2        Means redefining the meaning of beauty. An ama...
# 3        Born in East London Ive naturally been exposed...
# 4                                                      NaN
#                                ...
# 37244    nOur manufacturing organization Srikrishna Ban...
# 37245    We are leading manufacturer amp exporter of hi...
# 37246    Following proper safety measures in all aspect...
# 37247    Imran  Sons was established in the year 2015. ...
# 37248    R.K. Store was established in the year 2002. W...
# Name: company, Length: 37249, dtype: object

# %%
company_df = df['company']

# %%
company_df.head()
# Out:
# 0    Khoobsurat Overseas was established in the yea...
# 1    Intex Technologies India Ltd incorporated in 1...
# 2    Means redefining the meaning of beauty. An ama...
# 3    Born in East London Ive naturally been exposed...
# 4                                                  NaN
# Name: company, dtype: object

# %%
type(company_df)
# Out:
# pandas.core.series.Series

# %%
subset = df['company']
subset.head()
# Out:
# 0    Khoobsurat Overseas was established in the yea...
# 1    Intex Technologies India Ltd incorporated in 1...
# 2    Means redefining the meaning of beauty. An ama...
# 3    Born in East London Ive naturally been exposed...
# 4                                                  NaN
# Name: company, dtype: object

# %%
df.loc[[0,1,2,3]]
# Out:
#    firstname  lastname                                            company
# 0  Mr. Vijay   Balotia  Khoobsurat Overseas was established in the yea...
# 1   Rajinder     Kumar  Intex Technologies India Ltd incorporated in 1...
# 2      Sunil   Khurana  Means redefining the meaning of beauty. An ama...
# 3      Madan      Soni  Born in East London Ive naturally been exposed...

# %%
df.iloc[2]
df.head()
# Out:
#    firstname  lastname                                            company
# 0  Mr. Vijay   Balotia  Khoobsurat Overseas was established in the yea...
# 1   Rajinder     Kumar  Intex Technologies India Ltd incorporated in 1...
# 2      Sunil   Khurana  Means redefining the meaning of beauty. An ama...
# 3      Madan      Soni  Born in East London Ive naturally been exposed...
# 4    Parveen     Kumar                                                NaN

# %%
df.ix[2]
# Out:
# C:\Users\ayn-pc2\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
#  firstname                                                Sunil
#  lastname                                               Khurana
# company       Means redefining the meaning of beauty. An ama...
# Name: 2, dtype: object

# %%
subset = df.loc[:, ['company']]
subset.head()
# Out:
#                                              company
# 0  Khoobsurat Overseas was established in the yea...
# 1  Intex Technologies India Ltd incorporated in 1...
# 2  Means redefining the meaning of beauty. An ama...
# 3  Born in East London Ive naturally been exposed...
# 4                                                NaN

# %%
df['company'].astype(str)
# Out:
# 0        Khoobsurat Overseas was established in the yea...
# 1        Intex Technologies India Ltd incorporated in 1...
# 2        Means redefining the meaning of beauty. An ama...
# 3        Born in East London Ive naturally been exposed...
# 4                                                      nan
#                                ...
# 37244    nOur manufacturing organization Srikrishna Ban...
# 37245    We are leading manufacturer amp exporter of hi...
# 37246    Following proper safety measures in all aspect...
# 37247    Imran  Sons was established in the year 2015. ...
# 37248    R.K. Store was established in the year 2002. W...
# Name: company, Length: 37249, dtype: object

# %%
df['company'].describe()
# Out:
# count                                                 33142
# unique                                                33024
# top       Bata serves a million customers each day with ...
# freq                                                      9
# Name: company, dtype: object

# %%
df.describe()
# Out:
#         firstname  lastname                                            company
# count       37231     31744                                              33142
# unique       8953     10052                                              33024
# top           Mr.     Kumar  Bata serves a million customers each day with ...
# freq          363      1385                                                  9

# %%
#data = pd.read_csv("/path/to/csv/file.csv")
#data.rename(columns=lambda x: x.lower().replace(' ', '_'))
df = pd.read_csv('C:/Users/ayn-pc2/Desktop/T/update.csv')
#df.rename(columns=lambda x: x.Lower().replace('','_'))
df['company'].str.upper().replace('','_')
# Out:
# 0        KHOOBSURAT OVERSEAS WAS ESTABLISHED IN THE YEA...
# 1        INTEX TECHNOLOGIES INDIA LTD INCORPORATED IN 1...
# 2        MEANS REDEFINING THE MEANING OF BEAUTY. AN AMA...
# 3        BORN IN EAST LONDON IVE NATURALLY BEEN EXPOSED...
# 4                                                      NaN
#                                ...
# 37244    NOUR MANUFACTURING ORGANIZATION SRIKRISHNA BAN...
# 37245    WE ARE LEADING MANUFACTURER AMP EXPORTER OF HI...
# 37246    FOLLOWING PROPER SAFETY MEASURES IN ALL ASPECT...
# 37247    IMRAN  SONS WAS ESTABLISHED IN THE YEAR 2015. ...
# 37248    R.K. STORE WAS ESTABLISHED IN THE YEAR 2002. W...
# Name: company, Length: 37249, dtype: object

# %%
# Output data to a CSV file
# Typically, I don't want row numbers in my output file, hence index=False.
# To avoid character issues, I typically use utf8 encoding for input/output.
df.to_csv("comapny.csv", index=False, encoding='utf8')

# %%
#import matplotlib.pyplot as plt

# %%
#df['latituted'].plot(kind='hist', bins=100) plt.xlabel('latituted value')

# %%
#read first index of array
df["company"][0]
# Out:
# 'Khoobsurat Overseas was established in the year of 1985.. We are the Manufacturer Supplier Exporter of Sequined Shoes Punjabi Jutti House Slippers Beads Work Hand Made Mojaris Khussa Mojree Jens Casual Mojaree. Mojari For mans keeping in mind the current market trends we are providing a very fashionable range of Footwear. Our offered footwear is manufactured by our skilled and experienced professionals who are very well aware about the current fashion trends and design these sandals according to that.As one of the prominent manufacturers we are offering a vast range of Punjabi Mojari to our valued clients. Colorful Juttis offered by us are widely appreciated for its superior design and high finishes. We use superior quality leathers and raw materials in manufacturing these Juttis and offer high durability and long service life. Juttis offered by us are available in market at most economic rateThis designer dark tan color mojari with combination of white brocade is enhanced with diam
# ...

# %%
nltk.word_tokenize(df["company"][0])
# Out:
# ['Khoobsurat',
#  'Overseas',
#  'was',
#  'established',
#  'in',
#  'the',
#  'year',
#  'of',
#  '1985..',
#  'We',
#  'are',
#  'the',
#  'Manufacturer',
#  'Supplier',
#  'Exporter',
#  'of',
#  'Sequined',
#  'Shoes',
#  'Punjabi',
#  'Jutti',
#  'House',
#  'Slippers',
#  'Beads',
#  'Work',
#  'Hand',
#  'Made',
#  'Mojaris',
#  'Khussa',
#  'Mojree',
#  'Jens',
#  'Casual',
#  'Mojaree',
#  '.',
#  'Mojari',
#  'For',
#  'mans',
#  'keeping',
#  'in',
#  'mind',
#  'the',
#  'current',
#  'market',
#  'trends',
#  'we',
#  'are',
#  'providing',
#  'a',
#  'very',
#  'fashionable',
#  'range',
#  'of',
#  'Footwear',
#  '.',
#  'Our',
#  'offered',
#  'footwear',
#  'is',
#  'manufactured',
#  'by',
#  'our',
#  'skilled',
#  'and',
#  'experienced',
#  'professionals',
#  'who',
#  'are',
#  'very',
#  'well',
#  'aware',
#  'about',
#  'the',
#  'current',
#  'fashion',
#  'trends',
#  'and',
#  'design',
#  'these',
#  'sandals',
#  'according',
#  'to',
#  'that.As',
# ...

# %%
nltk.tokenize.WhitespaceTokenizer().tokenize(df["company"][0])
# Out:
# ['Khoobsurat',
#  'Overseas',
#  'was',
#  'established',
#  'in',
#  'the',
#  'year',
#  'of',
#  '1985..',
#  'We',
#  'are',
#  'the',
#  'Manufacturer',
#  'Supplier',
#  'Exporter',
#  'of',
#  'Sequined',
#  'Shoes',
#  'Punjabi',
#  'Jutti',
#  'House',
#  'Slippers',
#  'Beads',
#  'Work',
#  'Hand',
#  'Made',
#  'Mojaris',
#  'Khussa',
#  'Mojree',
#  'Jens',
#  'Casual',
#  'Mojaree.',
#  'Mojari',
#  'For',
#  'mans',
#  'keeping',
#  'in',
#  'mind',
#  'the',
#  'current',
#  'market',
#  'trends',
#  'we',
#  'are',
#  'providing',
#  'a',
#  'very',
#  'fashionable',
#  'range',
#  'of',
#  'Footwear.',
#  'Our',
#  'offered',
#  'footwear',
#  'is',
#  'manufactured',
#  'by',
#  'our',
#  'skilled',
#  'and',
#  'experienced',
#  'professionals',
#  'who',
#  'are',
#  'very',
#  'well',
#  'aware',
#  'about',
#  'the',
#  'current',
#  'fashion',
#  'trends',
#  'and',
#  'design',
#  'these',
#  'sandals',
#  'according',
#  'to',
#  'that.As',
#  'one',
# ...

# %%
nltk.tokenize.WordPunctTokenizer().tokenize(df["company"][0])
# Out:
# ['Khoobsurat',
#  'Overseas',
#  'was',
#  'established',
#  'in',
#  'the',
#  'year',
#  'of',
#  '1985',
#  '..',
#  'We',
#  'are',
#  'the',
#  'Manufacturer',
#  'Supplier',
#  'Exporter',
#  'of',
#  'Sequined',
#  'Shoes',
#  'Punjabi',
#  'Jutti',
#  'House',
#  'Slippers',
#  'Beads',
#  'Work',
#  'Hand',
#  'Made',
#  'Mojaris',
#  'Khussa',
#  'Mojree',
#  'Jens',
#  'Casual',
#  'Mojaree',
#  '.',
#  'Mojari',
#  'For',
#  'mans',
#  'keeping',
#  'in',
#  'mind',
#  'the',
#  'current',
#  'market',
#  'trends',
#  'we',
#  'are',
#  'providing',
#  'a',
#  'very',
#  'fashionable',
#  'range',
#  'of',
#  'Footwear',
#  '.',
#  'Our',
#  'offered',
#  'footwear',
#  'is',
#  'manufactured',
#  'by',
#  'our',
#  'skilled',
#  'and',
#  'experienced',
#  'professionals',
#  'who',
#  'are',
#  'very',
#  'well',
#  'aware',
#  'about',
#  'the',
#  'current',
#  'fashion',
#  'trends',
#  'and',
#  'design',
#  'these',
#  'sandals',
#  'according',
#  'to',
# ...

# %%
nltk.tokenize.TreebankWordTokenizer().tokenize(df["company"][0])
# Out:
# ['Khoobsurat',
#  'Overseas',
#  'was',
#  'established',
#  'in',
#  'the',
#  'year',
#  'of',
#  '1985..',
#  'We',
#  'are',
#  'the',
#  'Manufacturer',
#  'Supplier',
#  'Exporter',
#  'of',
#  'Sequined',
#  'Shoes',
#  'Punjabi',
#  'Jutti',
#  'House',
#  'Slippers',
#  'Beads',
#  'Work',
#  'Hand',
#  'Made',
#  'Mojaris',
#  'Khussa',
#  'Mojree',
#  'Jens',
#  'Casual',
#  'Mojaree.',
#  'Mojari',
#  'For',
#  'mans',
#  'keeping',
#  'in',
#  'mind',
#  'the',
#  'current',
#  'market',
#  'trends',
#  'we',
#  'are',
#  'providing',
#  'a',
#  'very',
#  'fashionable',
#  'range',
#  'of',
#  'Footwear.',
#  'Our',
#  'offered',
#  'footwear',
#  'is',
#  'manufactured',
#  'by',
#  'our',
#  'skilled',
#  'and',
#  'experienced',
#  'professionals',
#  'who',
#  'are',
#  'very',
#  'well',
#  'aware',
#  'about',
#  'the',
#  'current',
#  'fashion',
#  'trends',
#  'and',
#  'design',
#  'these',
#  'sandals',
#  'according',
#  'to',
#  'that.As',
#  'one',
# ...

# %%
#SnowBall stemmer
snowballStemmedWords = [nltk.stem.SnowballStemmer("english").stem(word) for word in words]

# %%
df['SnowballStemmedWords'] = pd.Series(snowballStemmedWords)
df
# Out:
#     OriginalWords SnowballStemmedWords
# 0      Khoobsurat           khoobsurat
# 1        Overseas              oversea
# 2             was                  was
# 3     established            establish
# 4              in                   in
# ..            ...                  ...
# 165             a                    a
# 166       stylish              stylish
# 167           yet                  yet
# 168   traditional               tradit
# 169         look.                look.
#
# [170 rows x 2 columns]

# %%
#LEMMATIZATION
words  = nltk.tokenize.WhitespaceTokenizer().tokenize(Location["company"][0])

# %%
df = pd.DataFrame()
df['OriginalWords'] = pd.Series(words)

# %%
#WordNet Lemmatization
wordNetLemmatizedWords = [nltk.stem.WordNetLemmatizer().lemmatize(word) for word in words]
df['WordNetLemmatizer'] = pd.Series(wordNetLemmatizedWords)
df
# Out:
#     OriginalWords WordNetLemmatizer
# 0      Khoobsurat        Khoobsurat
# 1        Overseas          Overseas
# 2             was                wa
# 3     established       established
# 4              in                in
# ..            ...               ...
# 165             a                 a
# 166       stylish           stylish
# 167           yet               yet
# 168   traditional       traditional
# 169         look.             look.
#
# [170 rows x 2 columns]
